# %%
import pandas as pd
import ast
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./df_test.csv', sep='\t')

# %%
g = sns.FacetGrid(df, col='dataset', row="tokenizer_type",
                  margin_titles=True, height=5, ylim=(0, 50), xlim=(0, 48000))
g.map(sns.pointplot, "vocab_size", "freq@95%", ci=None)
g.add_legend()
# Out:
# /home/edo/miniconda3/envs/align/lib/python3.8/site-packages/seaborn/axisgrid.py:670: UserWarning: Using the pointplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
time_stats = ast.literal_eval(open('./time_stats.txt').read())

# %%
time_stats['en_ga'][0][0][0] # dataset : [char, unigram, bpe][train, token][src, tgt]
# Out:
# ('en_char_0.118k', 0.03304266929626465)

# %%
df = pd.DataFrame(columns=['dataset', 'model_type', 'train/tok', 'src/tgt', 'time'])

for key in time_stats.keys():
    for model in time_stats[key]:
        for train\tok in model:
