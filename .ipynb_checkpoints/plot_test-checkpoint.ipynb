# %%
import pandas as pd
import ast
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
datasets = [
            'am',
            'ar',
            'chr',
            'cs',
            'en',
            'fi',
            'ga',
            'hi',
            'it',
            #'ja',
            'lt',
            'mr',
            #'my',
            #'sv',
            #'syr',
            #'zu',
            #'ojb'
            
            ]

# %%
for dataset in datasets:
    df = pd.read_csv(f'./stats/{dataset}.csv', sep='\t')

    g2 = sns.FacetGrid(df, row='lang', hue="tokenizer",
                      margin_titles=True, 
                       height=5, 
                       #ylim=(0, 280),
                       xlim=(0, 8250),
                       palette='tab10')
    g2.map(sns.lineplot, "vocab_size", "freq@95%", ci=None, linewidth=3)
    g2.add_legend()
    g2.savefig(f'./plots/freq@95_{dataset}.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
#       1 for dataset in datasets:
# ----> 2     df = pd.read_csv(f'./stats/{dataset}.csv', sep='\t')
#       4     g2 = sns.FacetGrid(df, row='lang', hue="tokenizer",
#       5                       margin_titles=True,
#       6                        height=5,
#       7                        #ylim=(0, 280),
#       8                        xlim=(0, 8250),
#       9                        palette='tab10')
#      10     g2.map(sns.lineplot, "vocab_size", "freq@95%", ci=None, linewidth=3)
#
# File ~/miniconda3/envs/align/lib/python3.8/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/align/lib/python3.8/site-packages/pandas/io/parsers/readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File ~/miniconda3/envs/align/lib/python3.8/site-packages/pandas/io/parsers/readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File ~/miniconda3/envs/align/lib/python3.8/site-packages/pandas/io/parsers/readers.py:933, in TextFileReader.__init__(self, f, engine, **kwds)
#     930     self.options["has_index_names"] = kwds["has_index_names"]
#     932 self.handles: IOHandles | None = None
# --> 933 self._engine = self._make_engine(f, self.engine)
#
# File ~/miniconda3/envs/align/lib/python3.8/site-packages/pandas/io/parsers/readers.py:1217, in TextFileReader._make_engine(self, f, engine)
#    1213     mode = "rb"
#    1214 # error: No overload variant of "get_handle" matches argument types
#    1215 # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1216 # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1217 self.handles = get_handle(  # type: ignore[call-overload]
#    1218     f,
#    1219     mode,
#    1220     encoding=self.options.get("encoding", None),
#    1221     compression=self.options.get("compression", None),
#    1222     memory_map=self.options.get("memory_map", False),
#    1223     is_text=is_text,
#    1224     errors=self.options.get("encoding_errors", "strict"),
#    1225     storage_options=self.options.get("storage_options", None),
#    1226 )
#    1227 assert self.handles is not None
#    1228 f = self.handles.handle
#
# File ~/miniconda3/envs/align/lib/python3.8/site-packages/pandas/io/common.py:789, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784 elif isinstance(handle, str):
#     785     # Check whether the filename is to be opened in binary mode.
#     786     # Binary mode does not support 'encoding' and 'newline'.
#     787     if ioargs.encoding and "b" not in ioargs.mode:
#     788         # Encoding
# --> 789         handle = open(
#     790             handle,
#     791             ioargs.mode,
#     792             encoding=ioargs.encoding,
#     793             errors=errors,
#     794             newline="",
#     795         )
#     796     else:
#     797         # Binary mode
#     798         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: './stats/ar.csv'

# %%
for dataset in datasets:
    df = pd.read_csv(f'./stats/{dataset}.csv', sep='\t')

    g2 = sns.FacetGrid(df, row='lang', hue="tokenizer",
                      margin_titles=True, 
                       height=5, 
                       ylim=(15, 65),
                       xlim=(0, 8500),
                       palette='tab10')
    g2.map(sns.lineplot, "vocab_size", "avg_len", ci=None, linewidth=3)
    g2.axes[0,0].set_ylabel('μ')
    #g2.axes[0,1].set_ylabel('μ')
    g2.axes[0,0].set_xlabel('Vocabulary size')
    #g2.axes[0,1].set_xlabel('Vocabulary size')
    
    g2.add_legend()
    g2.savefig(f'./plots/μ_{dataset}.png')

# %%
for dataset in datasets:
    df = pd.read_csv(f'./stats/{dataset}.csv', sep='\t')

    g2 = sns.FacetGrid(df, row='dataset', col='lang', hue="model_type",
                      margin_titles=True, 
                       height=5, 
                       #ylim=(15, 65),
                       xlim=(0, 8500),
                       palette='tab10')
    g2.map(sns.lineplot, "vocab_size", "train", ci=None, linewidth=3)
    
    g2.add_legend()
    g2.savefig(f'./plots/train_{dataset}.png')

# %%
for dataset in datasets:
    df = pd.read_csv(f'./stats/{dataset}.csv', sep='\t')

    g2 = sns.FacetGrid(df, row='dataset', col='lang', hue="model_type",
                      margin_titles=True, 
                       height=5, 
                       #ylim=(15, 65),
                       xlim=(0, 8500),
                       palette='tab10')
    g2.map(sns.lineplot, "vocab_size", "token", ci=None, linewidth=3)
    
    g2.add_legend()
    g2.savefig(f'./plots/token_{dataset}.png')

# %%
for dataset in datasets:
    df = pd.read_csv(f'./stats/{dataset}.csv', sep='\t')

    g2 = sns.FacetGrid(df, row='lang', hue="tokenizer",
                      margin_titles=True, 
                       height=5, 
                       #ylim=(0, 280),
                       xlim=(0, 9000),
                       palette='tab10')
    g2.map(sns.lineplot, "vocab_size", "weighted", ci=None, linewidth=3)
    g2.add_legend()
    g2.savefig(f'./plots/weighted_{dataset}.png')
